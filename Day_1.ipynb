# %% [markdown]
# 1. What is Computer Vision
# 2. Digital Images: Pixels & Channels
# 3. Image Coordinate System
# 4. Dataset Image Formats

# %% [markdown]
# Open - CV

# %%
import cv2

img = cv2.imread(r"E:\tojii.jpg")
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# PIL

# %%
from PIL import Image

img = Image.open("E:/tojii.jpg")
img.show()

# %% [markdown]
# Converting RGB to Grayscale

# %%
import cv2

img = cv2.imread(r"E:\tojii.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(0)

# %%
print(img.shape)
# Out:
# (6000, 10667, 3)

# %% [markdown]
# Tensorflow

# %%
import tensorflow as tf

img = tf.io.read_file("E:\tojii.jpg")
img = tf.image.decode_jpg(img, channels=3)
img = tf.image.resize(img, (244, 244))
print(img.show)
